# %%
cake_len, cake_width = (17.69, 28.3)
cake_area = 500.62700000000007
requests =  [33.54, 36.86, 83.28, 18.27, 91.04, 48.52, 75.42, 90.13]
noise = 0.04

# %%
def transform_list(strings):
    result = []
    for i, s in enumerate(strings):
        result.append(s)
        # Add an extra element after every second string
        if (i + 1) % 2 == 0:
            result.append(s + 'x')
    return result

# Example list of strings
strings = ['a', 'b', 'c', 'd', 'e', 'f', 'g']

strings[:3]
# Out:
# ['a', 'b', 'c']

# %%
# Translate the calculated width into coordinates where a vertical line is cut
coord_width = [[x_coord, 0] for x_coord in x_width]
coord_length = [[x_coord, cake_len] for x_coord in x_width]

# List of coordinates [cut1_top, cut1_bottom, ..., cutN_top, cutNbottom]
vertical_cuts = [val for pair in zip(coord_width, coord_length) for val in pair]

# %%
import json
import matplotlib.pyplot as plt
import os

root_path = '/Users/robinlinzmayer/Documents/columbia_university/fall_2024/programming/PieceOfCake/requests/'
# Read the JSON file
with open(f'{root_path}group_2/hard.json', 'r') as file:
    data = json.load(file)

# Extract the list of requests
requests = data["requests"]

# Plot the histogram
plt.hist(requests, bins=5, edgecolor='black')
plt.xlabel('Request Values')
plt.ylabel('Frequency')
plt.title('Group 2 Hard Penalty 25')
plt.show()

# %%
# Read the JSON file
with open(f'{root_path}group_4/hard.json', 'r') as file:
    data = json.load(file)

# Extract the list of requests
requests = data["requests"]

# Plot the histogram
plt.hist(requests, bins=5, edgecolor='black')
plt.xlabel('Request Values')
plt.ylabel('Frequency')
plt.title('Group 4 Hard Penalty 76')
plt.show()

# %%
# Read the JSON file
with open(f'{root_path}group_6/hard.json', 'r') as file:
    data = json.load(file)

# Extract the list of requests
requests = data["requests"]

# Plot the histogram
plt.hist(requests, bins=5, edgecolor='black')
plt.xlabel('Request Values')
plt.ylabel('Frequency')
plt.title('Group 6 Hard Penalty 189')
plt.show()

# %%
# Read the JSON file
with open(f'{root_path}group_7/hard.json', 'r') as file:
    data = json.load(file)

# Extract the list of requests
requests = data["requests"]

# Plot the histogram
plt.hist(requests, bins=5, edgecolor='black')
plt.xlabel('Request Values')
plt.ylabel('Frequency')
plt.title('Group 7 Hard Penalty 11')
plt.show()

# %%
# Read the JSON file
with open(f'{root_path}group_9/hard.json', 'r') as file:
    data = json.load(file)

# Extract the list of requests
requests = data["requests"]

# Plot the histogram
plt.hist(requests, bins=5, edgecolor='black')
plt.xlabel('Request Values')
plt.ylabel('Frequency')
plt.title('Group 9 Hard Penalty 179')
plt.show()

# %%
import math
req = 130
tol = 0.05
side = math.sqrt(2 * req)
new_area = req + (req*tol)
side, new_area, req*tol
# Out:
# (16.1245154965971, 136.5, 6.5)

# %%
cake_area = 136.56719999999999
valid_area = req + (req*tol)
print(valid_area)
if cake_area > valid_area:
    area_to_chop = cake_area - valid_area
    print(area_to_chop)
# Out:
# 136.5
# 0.0671999999999855

# %%
x = 90.9 /9.24
a1 = 9.83*9.24
a2 = 9.84*9.24
a1, a2
# Out:
# (90.8292, 90.9216)

# %%
cake_area = 136.56719999999999
remaining = cake_area - 90.83
chop = remaining - 40.4
chop
# Out:
# 5.337199999999989

# %%
side = math.sqrt(2 * area_to_chop)
side
# Out:
# 0.15999999999999118

# %%
90+(90*0.25)
# Out:
# 112.5

# %%
a = 79.19
h = (28.3 - 21.06)

b = (2*a) / h
b
# Out:
# 21.8756906077348
